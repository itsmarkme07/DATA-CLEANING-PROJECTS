# %%
import pandas as pd

df = pd.read_csv('C:/Users/i5/Desktop/DATA ANALYST BOOTCAMP/data cleaning projects/UCI_Credit_Card.csv')
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.rename(columns={
    'PAY_0': 'PAY_1',
    'default.payment.next.month': 'default_next_month'
}, inplace=True)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_next_month
# ...

# %%
df['SEX'] = df['SEX'].replace({1: 'Male', 2: 'Female'}).astype('category')

education_map = {1: 'Graduate School', 2: 'University', 3: 'High School', 4: 'Others', 5: 'Unknown', 6: 'Unknown', 0: 'Unknown'}
df['EDUCATION'] = df['EDUCATION'].replace(education_map).astype('category')

marriage_map = {1: 'Married', 2: 'Single', 3: 'Others', 0: 'Unknown'}
df['MARRIAGE'] = df['MARRIAGE'].replace(marriage_map).astype('category')

df['default_next_month'] = df['default_next_month'].replace({0: 'No Default', 1: 'Default'}).astype('category')

df
# Out:
#           ID  LIMIT_BAL     SEX    EDUCATION MARRIAGE  AGE  PAY_1  PAY_2  \
# 0          1    20000.0  Female   University  Married   24      2      2
# 1          2   120000.0  Female   University   Single   26     -1      2
# 2          3    90000.0  Female   University   Single   34      0      0
# 3          4    50000.0  Female   University  Married   37      0      0
# 4          5    50000.0    Male   University  Married   57     -1      0
# ...      ...        ...     ...          ...      ...  ...    ...    ...
# 29995  29996   220000.0    Male  High School  Married   39      0      0
# 29996  29997   150000.0    Male  High School   Single   43     -1     -1
# 29997  29998    30000.0    Male   University   Single   37      4      3
# 29998  29999    80000.0    Male  High School  Married   41      1     -1
# 29999  30000    50000.0    Male   University  Married   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
pay_status_map = {
    -2: 'No Consumption',
    -1: 'Paid Duly',
     0: 'Paid Duly',
     1: '1 Month Delay',
     2: '2 Months Delay',
     3: '3 Months Delay',
     4: '4 Months Delay',
     5: '5 Months Delay',
     6: '6 Months Delay',
     7: '7 Months Delay',
     8: '8 Months Delay',
     9: '9+ Months Delay'
}
df['PAY_1'] = df['PAY_1'].replace(pay_status_map).astype('category')

pay_columns = ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

for col in pay_columns:
    df[col] = df[col].replace(pay_status_map).astype('category')

df
# Out:
#           ID  LIMIT_BAL     SEX    EDUCATION MARRIAGE  AGE           PAY_1  \
# 0          1    20000.0  Female   University  Married   24  2 Months Delay
# 1          2   120000.0  Female   University   Single   26       Paid Duly
# 2          3    90000.0  Female   University   Single   34       Paid Duly
# 3          4    50000.0  Female   University  Married   37       Paid Duly
# 4          5    50000.0    Male   University  Married   57       Paid Duly
# ...      ...        ...     ...          ...      ...  ...             ...
# 29995  29996   220000.0    Male  High School  Married   39       Paid Duly
# 29996  29997   150000.0    Male  High School   Single   43       Paid Duly
# 29997  29998    30000.0    Male   University   Single   37  4 Months Delay
# 29998  29999    80000.0    Male  High School  Married   41   1 Month Delay
# 29999  30000    50000.0    Male   University  Married   46       Paid Duly
#
# ...

# %%
duplicates = df.duplicated().sum()
print(f"Duplicates found: {duplicates}")

df = df.drop_duplicates()
# Out:
# Duplicates found: 0

# %%
print(df.isnull().sum())
# Out:
# ID                    0
# LIMIT_BAL             0
# SEX                   0
# EDUCATION             0
# MARRIAGE              0
# AGE                   0
# PAY_1                 0
# PAY_2                 0
# PAY_3                 0
# PAY_4                 0
# PAY_5                 0
# PAY_6                 0
# BILL_AMT1             0
# BILL_AMT2             0
# BILL_AMT3             0
# BILL_AMT4             0
# BILL_AMT5             0
# BILL_AMT6             0
# PAY_AMT1              0
# PAY_AMT2              0
# PAY_AMT3              0
# PAY_AMT4              0
# PAY_AMT5              0
# PAY_AMT6              0
# default_next_month    0
# dtype: int64
